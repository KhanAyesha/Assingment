# %% [markdown]
# 1. What are the differences between operators and values in the following?

# %% [markdown]
# *,-,/,+ are mathematical operators. They don't have datatype. They are use to perform some operations like multiplication, subtraction, division and multiplication respectively. -87.8 and 6 are values and they have a particular data type like float and int.

# %% [markdown]
# 2. What is the difference between string and variable?

# %% [markdown]
# A string is written between quotes ("") /('') A variable is basically the name of the location in the primary memory of your computer. This can be chosen by you. A variable can store everything from strings to numbers.

# %% [markdown]
# 3. Describe three different data forms.

# %%
String: A string value is a collection of one or more characters put in single, double  quotes
eg. name='Ayesha'

List: A list object is an ordered collection of one or more data items, not necessarily of the same type, put in square brackets.
eg. mylist=['a', 1, 4+9j]
A list can alo be created as mylist=list('a', 1, 4+9j)

Tuple: Tuple is same as loop. But loops are immutable. Tuples are used to write-protect data and are usually faster than lists as they cannot change dynamically.
eg. mytuple=('a', 1, 4+9j)

# %% [markdown]
# 4. What makes up an expression? What are the functions of all expressions?

# %% [markdown]
# An expression is a combination of values, variables, operators, and calls to functions. Expressions need to be evaluated.

# %% [markdown]
# 5. In this chapter, assignment statements such as spam = 10 were added. What's the difference between a declaration and an expression?

# %% [markdown]
# A Python expression can be defined as any element in our program that evaluates to some value.
#
# An expression evaluates to a value. A statement does something. Statements represent an action or command e.g print statements, assignment statements. Expression is a combination of variables, operations and values that yields a result value.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# ans. 22

# %% [markdown]
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
# 'spam' * 3
#
# The output of both will be same 'spamspamspam'

# %% [markdown]
# 8. Why is it that eggs is a true variable name but 100 is not?
#
# Because there are rules while defining a varaible name which are to be followed. Following are the rules we need to take care while defining varibale name:
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)

# %% [markdown]
# 9. Which of the following three functions may be used to convert a value to an integer, a floating-point number, or a string?

# %% [markdown]
# A floating point number for sure. It can also be converted using string, but this is not true in all cases.

# %% [markdown]
# 10. What is the error caused by this expression? What would you do about it?
#
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# The error encountered is TypeError: can only concatenate str (not "int") to str.
# To solve the error we can just convert 99 to string format as 'I have eaten ' +  str(99) + ' burritos.'
