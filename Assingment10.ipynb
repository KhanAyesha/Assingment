# %% [markdown]
# 1. How do you distinguish between shutil.copy() and shutil.copytree()?
#
# ans:shutil.copy() method in Python is used to copy the content of source file to destination file or directory.
#     shutil.copytree() method recursively copies an entire directory tree rooted at source (src) to the destination directory.

# %% [markdown]
# 2. What function is used to rename files??
#
# ans: rename() file is a method used to rename a file or a directory in Python

# %% [markdown]
# 3. What is the difference between the delete functions in the send2trash and shutil modules?
#
# ans:The send2trash functions will move a file or folder to the recycle bin, while shutil functions will permanently delete files and folders

# %% [markdown]
# 4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?
#
# ans:open() method

# %% [markdown]
# 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder

# %%
import os
import glob
import shutil
def copy(file_type, source, destination):
    files_grabbed = []
    for files in types:
        for i in glob.glob(source+'\*'+files):
            files_grabbed.append(i)
    for files in files_grabbed:
        dest = shutil.copy(files, destination)

# %%
types = ('*.pdf', '*.jpg')
source=r'C:\Users\ayesha\Downloads\tree'
destiantion=r'C:\Users\ayesha\Downloads\tree_new'
copy(types, source, destination)
