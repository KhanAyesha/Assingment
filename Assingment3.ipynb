# %% [markdown]
# 1. What is the benefit of including functions in program ?
#
# ans:Reducing duplication of code
#
#     Decomposing complex problems into simpler pieces
#
#     Improving clarity of the code
#
#     Reuse of code
#
#     Information hiding

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?
#
# ans: when it's called

# %% [markdown]
# 3. What statement causes a feature to be created?
#
# ans:Probably you mean function. Function is created using def function.

# %% [markdown]
# 3. What is the distinction between a function and a call to a function?
#
# ans:A function is procedure to achieve a particular result while function call is using this function to achive that task

# %% [markdown]
# 5. In a Python application, how many global scopes are there? How many local scopes are there?
#
# ans: Didn't understand the question. There is only one global local scope and one local scope.

# %% [markdown]
# 6. When a function call returns, what happens to variables in the local scope?
#
# ans: When the execution of the function terminates (returns), the local variables are destroyed

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# ans:In general, a function takes arguments (if any), performs some operations, and returns a value (or object). The value that a function returns to the caller is generally known as the function's return value.
# yes it is possible to have return value in an expression.

# %% [markdown]
# 8. What is the return value of a call to a function that does not have a return statement?
#
# ans: Nonetype

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?
#
# ans: By adding keyword global

# %% [markdown]
# 10. What data form does None belong to?
#
# ans: None is a data type of its own (NoneType) and only None can be None.

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?
#
# ans: generally import statement imports the library(if is the name of authentic and properly installed otherwise it will throw an error).
#     But it in this case it will throw error as there is no library named areallyourpetsnamederic in python.

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# ans:spam.bacon()

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# ans: Use try and error block for the code piece that can throw error

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# ans:Basically the code that can possibly give error is placed in try clause. If the try block throws error then the code which should be executed is placed in except clause.
